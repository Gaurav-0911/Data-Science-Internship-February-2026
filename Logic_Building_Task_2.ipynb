# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaurav-0911/Data-Science-Internship-February-2026/blob/main/Logic_Building_Task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Task 2: Feb Internship Logic Building Task

# %% [markdown]
# #Problem 1: Unique Words in a Sentence

# %%
# Taking input from user
sentence = input("Enter sentence: ")

# Step 1: Split sentence into words
words = sentence.split()

# Step 2: Convert list to set (removes duplicates)
unique_words = set(words)

# Step 3: Print results
print("Unique words count:", len(unique_words))
print("Unique words:", unique_words)
# Out:
# Enter sentence: Ensure your Python code is clean, organized, and well-structured.
# Unique words count: 9
# Unique words: {'Ensure', 'is', 'and', 'code', 'well-structured.', 'clean,', 'organized,', 'your', 'Python'}

# %% [markdown]
# #Problem 2: Highest Salary from Employee Data

# %%
# Employee dictionary
employees = {
    "Aman": 80000,
    "Anita": 68000,
    "Kiran": 72000
}

# Find employee with highest salary
highest_employee = max(employees, key=employees.get)

# Print result
print("Highest Salary:", highest_employee, "-", employees[highest_employee])
# Out:
# Highest Salary: Aman - 80000

# %% [markdown]
# #Problem 3: Find Maximum and Minimum Values

# %%
# Given list
numbers = [55,69,58,78,96,26]

# Step 1: Initialize max and min with first element
maximum = numbers[0]
minimum = numbers[0]

# Step 2: Loop through list
for num in numbers:
    if num > maximum:
        maximum = num
    if num < minimum:
        minimum = num

# Step 3: Print results
print("List:", numbers)
print("Max:", maximum)
print("Min:", minimum)
# Out:
# List: [55, 69, 58, 78, 96, 26]
# Max: 96
# Min: 26

# %% [markdown]
# #Problem 4: Count Products Above a Price Threshold

# %%
# Given list of product prices
prices = [550, 1300, 899, 1400, 1400]

# Counter variable
count = 0

# Loop through prices
for price in prices:
    if price > 1000:
        count += 1

# Print result
print("Products above 1000:", count)
# Out:
# Products above 1000: 3

# %% [markdown]
# #Problem 5: Calculate Attendance Percentage

# %%
# Given attendance list
attendance = ["P", "P", "A", "A", "A"]

# Step 1: Count total days
total_days = len(attendance)

# Step 2: Count number of Present days
present_count = 0

for day in attendance:
    if day == "P":
        present_count += 1

# Step 3: Calculate percentage
attendance_percentage = (present_count / total_days) * 100

# Step 4: Print result
print("Attendance Percentage:", attendance_percentage)
# Out:
# Attendance Percentage: 40.0

# %% [markdown]
# #Problem 6: Remove Duplicate Phone Numbers

# %%
# Given list of phone numbers
phone_numbers = [9876595810, 9695841123, 9695841123]
# Convert list to set (removes duplicates)
unique_numbers = set(phone_numbers)

# Print result
print("Unique phone numbers:", unique_numbers)
# Out:
# Unique phone numbers: {9876595810, 9695841123}

# %% [markdown]
# #Problem 7: Count Character Frequency

# %%
# Given string
text = "Dictionary"

# Empty dictionary to store frequency
char_count = {}

# Loop through each character
for ch in text:
    if ch in char_count:
        char_count[ch] += 1
    else:
        char_count[ch] = 1

# Print result
print(char_count)
# Out:
# {'D': 1, 'i': 2, 'c': 1, 't': 1, 'o': 1, 'n': 1, 'a': 1, 'r': 1, 'y': 1}

# %% [markdown]
# #Problem 8: Convert List to Tuple

# %%
# Given list
numbers = [40, 60, 30]

# Convert list to tuple
numbers_tuple = tuple(numbers)

# Print result
print("Tuple:", numbers_tuple)
# Out:
# Tuple: (40, 60, 30)

# %% [markdown]
# #Problem 9: Check if a Key Exists in a Dictionary

# %%
# Given dictionary
employees = {
    "Ankit": 75000,
    "Anita": 68000,
    "Kiran": 72000
}

# Key to check
key_to_check = "Ravi"

# Check if key exists
if key_to_check in employees:
    print("Employee exists")
else:
    print("Employee does not exist")
# Out:
# Employee does not exist

# %% [markdown]
# #Problem 10: Calculate Average Marks

# %%
# Given list of marks
marks = [65, 80, 85, 75]

# Step 1: Calculate total marks
total = sum(marks)

# Step 2: Calculate number of subjects
count = len(marks)

# Step 3: Calculate average
average = total / count

# Print result
print("Average Marks:", average)
# Out:
# Average Marks: 76.25
